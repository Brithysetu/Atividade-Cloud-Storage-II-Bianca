# %% [markdown]
# <a href="https://colab.research.google.com/github/Brithysetu/Atividade-Cloud-Storage-II-Bianca/blob/main/Atividade_Cloud_Storage_II_Bianca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importar da biblioteca do pandas e dando um apelido = pd
import pandas as pd

# %%
'''Crie listas com 5 valores cada, com os respectivos nomes:
- matricula
- nome
- nota1
- nota2
- nota3
Os valores devem fazer sentido com cada lista.

Crie um dicionário a partir dessas listas com chave para cada lista.
Crie um dataframe com esse dicionário.
Gere um arquivo csv chamado notas_alunos.csv, suba para o storage em dfs_bruto
No dataframe, adicione uma coluna que realize a media das 3 notas
Gere um arquivo csv com o dataframe tratado chamado notas_alunos_finais.csv suba para o storagem em dfs_tratados

Entregue os códigos de forma individual.'''
# Out:
# 'Crie listas com 5 valores cada, com os respectivos nomes:\n- matricula\n- nome\n- nota1\n- nota2\n- nota3\nOs valores devem fazer sentido com cada lista.\n\nCrie um dicionário a partir dessas listas com chave para cada lista.\nCrie um dataframe com esse dicionário.\nGere um arquivo csv chamado notas_alunos.csv, suba para o storage em dfs_bruto\nNo dataframe, adicione uma coluna que realize a media das 3 notas\nGere um arquivo csv com o dataframe tratado chamado notas_alunos_finais.csv suba para o storagem em dfs_tratados\n\nEntregue os códigos de forma individual.'

# %%
nomes = ["ANDRE SILVA",
         "FONSECA LTDA",
         "ERICK BARRETO",
         "FILIPE MONTEIRO",
         "KELLI MACEDO",
]
matriculas = ["0001",
             "0002",
             "0003",
             "0004",
             "0005",

]
nota1 = [ 7,
         5,
          6,
          3,
          9
]
nota2 = [
    6,
    5,
    9,
    8,
    3
]
nota3 = [
    6,
    7,
    2,
    6,
    7
]
# montamos o dicionario de valores
dicionario_pessoas = {
    'nome': nomes,
    'matricula': matriculas,
    'notas1': nota1,
    'notas2': nota2,
    'notas3': nota3

}
# criar um DataFrame pd.DataFrame(aquilo que vc quer que vire um DataFrame)
df_escola = pd.DataFrame(dicionario_pessoas)
display(df_escola)
# Out:
#               nome matricula  notas1  notas2  notas3
# 0      ANDRE SILVA      0001       7       6       6
# 1     FONSECA LTDA      0002       5       5       7
# 2    ERICK BARRETO      0003       6       9       2
# 3  FILIPE MONTEIRO      0004       3       8       6
# 4     KELLI MACEDO      0005       9       3       7

# %%
df_escola.to_csv('notas_alunos_brutos.csv', index=False)
# jogar no storage e torna público

# %%
'''
Outro momento :
No dataframe, adicione uma coluna que realize a media das 3 notas
Gere um arquivo csv com o dataframe tratado chamado notas_alunos_finais.csv suba para o storagem em dfs_tratados

Entregue os códigos de forma individual.'''

# %%
#importar da biblioteca do pandas e dando um apelido = pd
import pandas as pd

# %%
#ler um arquivo .csv
df2= pd.read_csv("https://storage.googleapis.com/bucket-analise_de_dados_brithy/dfs_brutos/notas_alunos_brutos.csv")
#exibir via display o csv(df)
#display(df)
df2
# Out:
#               nome  matricula  notas1  notas2  notas3
# 0      ANDRE SILVA          1       7       6       6
# 1     FONSECA LTDA          2       5       5       7
# 2    ERICK BARRETO          3       6       9       2
# 3  FILIPE MONTEIRO          4       3       8       6
# 4     KELLI MACEDO          5       9       3       7

# %%
# criar um coluna media

#df2["media"] = round(df2['Nota1']+ (df2['Nota2']) + (df2['Nota3']) / 3)
df2['media'] = round((df2['notas1'] )+ (df2['notas2']) + (df2['notas3']) / 3,
2 )
display(df2)
# Out:
#               nome  matricula  notas1  notas2  notas3  media
# 0      ANDRE SILVA          1       7       6       6  15.00
# 1     FONSECA LTDA          2       5       5       7  12.33
# 2    ERICK BARRETO          3       6       9       2  15.67
# 3  FILIPE MONTEIRO          4       3       8       6  13.00
# 4     KELLI MACEDO          5       9       3       7  14.33

# %%
df2.to_csv('notas_alunos_finais.csv', index=False)
# jogar no storage e torna público

# %%
#url storage (https://storage.googleapis.com/bucket-analise_de_dados_brithy/dfs_tratados/notas_alunos_finais.csv)
